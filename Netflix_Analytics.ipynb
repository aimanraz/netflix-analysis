# %% [markdown]
# ## Import packages

# %%
#import packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read the data

# %%
#import the data
netflix = pd.read_csv('C:\\Users\\Admin\\Desktop\\Python Training\\dataset\\Netflix-Shows.csv', encoding='latin1')

# %%
# let see whatchu got there
netflix.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# ## Data Cleaning and others

# %%
#lets make the attributes name more friendly
netflix.columns = ['Title', 'Rating', 'RatingDescription', 'RatingLevel', 'ReleaseYear', \
                   'UserRating', 'UserRatingSize']

# %%
# Adjusted header 
netflix.head()
# Out:
#                    Title Rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                    RatingDescription  RatingLevel  \
# 0  crude and sexual humor, language and some drug...           80
# 1  strong violence, sexual content and adult lang...          100
# 2  Parents strongly cautioned. May be unsuitable ...           90
# 3  Parents strongly cautioned. May be unsuitable ...           90
# 4  Parental guidance suggested. May not be suitab...           70
#
#    ReleaseYear  UserRating  UserRatingSize
# 0         2004        82.0              80
# 1         2006         NaN              82
# 2         2016        98.0              80
# 3         2008        98.0              80
# 4         2014        94.0              80

# %%
# convert title,rating, rating level and year into category
netflix.Title = netflix.Title.astype('category')
netflix.Rating = netflix.Rating.astype('category')
#netflix.RatingDescription = netflix.RatingDescription.astype('category')
#netflix.ReleaseYear = netflix.ReleaseYear.astype('category')

# %%
# remove duplicates
netflix = netflix.drop_duplicates()

# %%
# maybe some more info?
netflix.info()
# heck we got some nullies on ratinglevel and user rating score
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              500 non-null    category
#  1   Rating             500 non-null    category
#  2   RatingDescription  467 non-null    object
#  3   RatingLevel        500 non-null    int64
#  4   ReleaseYear        500 non-null    int64
#  5   UserRating         256 non-null    float64
#  6   UserRatingSize     500 non-null    int64
# dtypes: category(2), float64(1), int64(3), object(1)
# memory usage: 49.5+ KB

# %%
# Since rating level with null is not usefull lets fill it with "Not_rated"
netflix.RatingDescription.fillna("Not_rated", inplace=True)

# %%
# how many nulls in User Rating?
netflix.UserRating.isnull().value_counts()
# 224 nulls
# Out:
# False    256
# True     244
# Name: UserRating, dtype: int64

# %%
# let see the list of ratings
rlist = netflix.Rating.cat.categories.tolist()
rlist
# Out:
# ['G',
#  'NR',
#  'PG',
#  'PG-13',
#  'R',
#  'TV-14',
#  'TV-G',
#  'TV-MA',
#  'TV-PG',
#  'TV-Y',
#  'TV-Y7',
#  'TV-Y7-FV',
#  'UR']

# %%
# Filling missing null values
# This method will fill null values depend of each Rating of User Rating mean average
for i in list(rlist):
    netflix[netflix['Rating'] == i] = netflix[netflix['Rating'] == i].replace(np.nan, netflix[netflix['Rating'] == i].UserRating.mean())

# %%
# lets do some quick check
netflix.info()
# well i do see something strange on User rating
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              500 non-null    category
#  1   Rating             500 non-null    category
#  2   RatingDescription  500 non-null    object
#  3   RatingLevel        500 non-null    int64
#  4   ReleaseYear        500 non-null    int64
#  5   UserRating         499 non-null    float64
#  6   UserRatingSize     500 non-null    int64
# dtypes: category(2), float64(1), int64(3), object(1)
# memory usage: 49.5+ KB

# %%
# Yup only'UR' rating have null value since it only have 1 value
netflix['Rating'].value_counts()
# Out:
# TV-14       106
# TV-MA        82
# PG           76
# G            53
# TV-Y         36
# TV-PG        33
# TV-G         29
# TV-Y7-FV     25
# TV-Y7        23
# R            14
# PG-13        12
# NR           10
# UR            1
# Name: Rating, dtype: int64

# %%
# Filling using foward fill method
netflix['UserRating'].fillna(method='ffill', inplace=True)

# %%
# Some quick check
netflix[netflix['Rating'] == 'UR']
# Out:
#          Title Rating                                  RatingDescription  \
# 38  White Girl     UR  This movie has not been rated. Intended for ad...
#
#     RatingLevel  ReleaseYear  UserRating  UserRatingSize
# 38          124         2016        77.0              82

# %%
#removing outlier
netflix.drop(netflix.index[netflix['ReleaseYear'] == 1940], inplace = True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Lets see what do we have
netflix.head(10)
# Out:
#                    Title Rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                    RatingDescription  RatingLevel  \
# 0  crude and sexual humor, language and some drug...           80
# 1  strong violence, sexual content and adult lang...          100
# 2  Parents strongly cautioned. May be unsuitable ...           90
# 3  Parents strongly cautioned. May be unsuitable ...           90
# 4  Parental guidance suggested. May not be suitab...           70
# 5  Parents strongly cautioned. May be unsuitable ...           90
# 6  For mature audiences.  May not be suitable for...          110
# 7  Parents strongly cautioned. May be unsuitable ...           90
# 8  For mature audiences.  May not be suitable for...          110
# 9  Parents strongly cautioned. May be unsuitable ...           90
#
#    ReleaseYear  UserRating  UserRatingSize
# 0         2004   82.000000              80
# 1         2006   85.285714              82
# 2         2016   98.000000              80
# 3         2008   98.000000              80
# 4         2014   94.000000              80
# 5         2016   95.000000              80
# 6         2013   97.000000              80
# 7         2017   91.000000              80
# 8         2015   98.000000              80
# 9         2016   96.000000              80

# %%
# Some basic statistic
netflix.describe().transpose()
# Out:
#                 count         mean        std     min          25%  \
# RatingLevel     499.0    68.821643  31.500339    10.0    41.000000
# ReleaseYear     499.0  2011.118236   7.161368  1976.0  2009.000000
# UserRating      499.0    80.388696   9.733819    55.0    74.421053
# UserRatingSize  499.0    80.973948   0.998655    80.0    80.000000
#
#                        50%     75%     max
# RatingLevel       70.00000    90.0   124.0
# ReleaseYear     2014.00000  2016.0  2017.0
# UserRating        82.87013    85.0    99.0
# UserRatingSize    80.00000    82.0    82.0

# %%
# This shows the capacity of the user rating and the range of rating of the viewer.
k1 = sns.kdeplot(netflix.RatingLevel, netflix.UserRating, shade=True, cmap='Blues_r')
k1b = sns.kdeplot(netflix.RatingLevel, netflix.UserRating, cmap='gist_gray_r')

# %%
# Which years had the most shows?
# According the the histogram, This illustrated number of movies started to growth every years in the netflix.
ReleaseSum = netflix['ReleaseYear'].value_counts().sort_values()
plt.figure(figsize=(10,5))
ReleaseSum.plot(title='Movie Release Year Within The Netlfix Shows',kind="bar")
plt.show()

# %%
lis = []
leg = []
for gen in netflix.Rating.cat.categories:
    lis.append(netflix[netflix.Rating == gen].ReleaseYear)
    leg.append(gen)
    
sns.set_style('whitegrid')   
fig, ax = plt.subplots()   
fig.set_size_inches(11.7,8.27)
h = plt.hist(lis, bins=30,stacked=True, rwidth=1, label=leg)
plt.title("Movie Rating Distribution ", fontsize=35)
plt.ylabel("Number of Movies", fontsize=25)
plt.xlabel("Rating", fontsize=25)
plt.yticks(fontsize=13)
plt.xticks(fontsize=13)
plt.legend(frameon=True, fancybox=True, shadow=True, prop={'size':15})
plt.show()

# %%
# Multi Stacked Histogram
sns.set_style('whitegrid')   
fig, ax = plt.subplots()   
fig.set_size_inches(11.7,8.27) # Size of A4 paper
h = plt.hist(netflix[netflix.ReleaseYear == 2016].Rating, color='Red')
plt.title("2016 Movie Distribution By Rated", fontsize=35)
plt.ylabel("Number of Movies", fontsize=25,)
plt.xlabel("Rated", fontsize=25)
plt.yticks(fontsize=13)
plt.xticks(fontsize=13)
plt.show()

# %%
netflix.RatingDescription
# Out:
# 0      crude and sexual humor, language and some drug...
# 1      strong violence, sexual content and adult lang...
# 2      Parents strongly cautioned. May be unsuitable ...
# 3      Parents strongly cautioned. May be unsuitable ...
# 4      Parental guidance suggested. May not be suitab...
#                              ...
# 989                    some rude humor and sports action
# 993            General Audiences. Suitable for all ages.
# 994            General Audiences. Suitable for all ages.
# 997                               Suitable for all ages.
# 998                               Suitable for all ages.
# Name: RatingDescription, Length: 499, dtype: object

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
bag = netflix.RatingDescription

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0,499):
    review = re.sub('[^a-zA-Z]', ' ', bag.iloc[i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['c r u e   n   e x u l   h u r ,   l n g u g e   n   e   r u g   c n e n',
#  'r n g   v l e n c e ,   e x u l   c n e n   n   u l   l n g u g e',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'l n g u g e   n   b r e f   v l e n c e',
#  'S u b l e   f r   l l   g e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'T h   v e   h   n   b e e n   r e .',
#  'S u b l e   f r   l l   g e .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'T h   v e   h   n   b e e n   r e .',
#  'T h   v e   h   n   b e e n   r e .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'b l   w r   v l e n c e ,   l n g u g e   h r u g h u   n   e   e x u l   e r l',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'T h   v e   h   n   b e e n   r e .',
#  'T h   v e   h   n   b e e n   r e .   I n e n e   f r   u l   n l   n     c n n   e x ,   v l e n c e ,   r u g ,   l n g u g e   r   h e r   u l   h e e .',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'N _ r e',
#  'N _ r e',
#  'T h   v e   h   n   b e e n   r e .',
#  'N _ r e',
#  'N _ r e',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'N _ r e',
#  'e   h e c   e l e e n ,   r u e   h u r   n   c n',
#  'p e r v v e   l n g u g e ,   e   e x u l   e r l ,   v l e n c e   n   r u g   u e',
#  'l   h e c   e l e e n',
#  'r n g   c r u e   e x u l   c n e n ,   p e r v v e   l n g u g e ,   n   r u g   u e',
#  'f r   c n ,   p e r l   n   b r e f   l n g u g e',
#  'e   e x u l   e r l ,   n   l n g u g e   h r u g h u',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'N _ r e',
#  'l n g u g e ,   e   r u g   u e ,   v l e n c e   n   p r l   n u',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'e   e x u l   e r l',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'N _ r e',
#  'N _ r e',
#  'N _ r e',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'N _ r e',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'T h   v e   h   n   b e e n   r e .',
#  'r n g   e x u l   c n e n   n   l n g u g e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'l n g u g e ,   r u g   c n e n ,   e x u l / n u ,   n   e   v l e n c e - l l   n v l v n g   e e n',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'h e c   e l e e n ,   c r   g e ,   c n   n   p e r l',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'h e c   e l e e n ,   n   c c e n   c e n e   n   e   u g g e v e   e r l',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'N _ r e',
#  'N _ r e',
#  'T h   v e   h   n   b e e n   r e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'N _ r e',
#  'N _ r e',
#  'N _ r e',
#  'N _ r e',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'R e r c e .   M   b e   n p p r p r e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'f r   h e c   e r l   n   l n g u g e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'N _ r e',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'N _ r e',
#  'N _ r e',
#  'l n g u g e   n   e   c r u e   e x u l   h u r',
#  'u l   c n e n ,   u l   l n g u g e   n   l   v l e n c e',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'e   e x - r e l e   e r l',
#  'c r u e   n   u g g e v e   h u r ,   n   f r   l n g u g e',
#  'h e c   e l e e n ,   b r e f   v l e n c e   n   n n u e n',
#  'S u b l e   f r   l l   g e .',
#  'e   v l e n c e   n   n e   e x u l   c e n e',
#  'h e c   e l e e n ,   c r   g e ,   e   l n g u g e   n   u g g e v e   h u r',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'F r   e   r u e   n   u g g e v e   e r l ,   n   f r   l n g u g e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'h e c   e r l   n v l v n g   h r e e n n g   b e h v r ,   n   f r   v l e n c e   n   e x u l',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'S u b l e   f r   l l   g e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'l n g u g e   n   e   e x u l   h u r',
#  'p e r v v e   r u g   c n e n   n   l n g u g e ,   e   v l e n c e   n   e x u l',
#  'S u b l e   f r   l l   g e .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'p e r v v e   e x u l   c n e n ,   b r e f   g r p h c   n u ,   l n g u g e   n   e   r u g   u e',
#  'P r e n   r n g l   c u n e .   M   b e   n p p r p r e   f r   c h l r e n   u n e r   1 3 .',
#  'l   c n   n   e   r u e   h u r',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'N _ r e',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'e   v l e n   c n e n   n   u r e   h e c   e l e e n',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'r n g   v l e n c e   n   l n g u g e   h r u g h u',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'l g u e ,   l n g u g e ,   e x u l   u n   n   v l e n c e',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'N _ r e',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'P r e n   r n g l   c u n e .   M   b e   u n u b l e   f r   c h l r e n   g e   1 4   n   u n e r .',
#  'F r   u r e   u e n c e .     M   n   b e   u b l e   f r   c h l r e n   1 7   n   u n e r .',
#  'e   c r   g e',
#  'e   r u e   h u r ,   l n g u g e   n   e   c r   c n',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'n e   c n   v l e n c e ,   e   c r   c r n   g e   n   l   l n g u g e',
#  'c - f   c n   v l e n c e   h r u g h u ,   b r e f   l n g u g e   n   e n r   k n g',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'f n   c n',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'f r   e   e q u e n c e   f   c r   c n   n   p e r l',
#  'f r   r u e   h u r   n   c n',
#  'f r   c n   n   e   r u e   h u r',
#  'S u b l e   f r   l l   g e .',
#  'c n   v l e n c e   h r u g h u ,   e   c r   g e ,   n   l n g u g e',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'f n   c n   n   l   l n g u g e',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'c n   n   e   r u e   h u r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'c n   n   v l e n c e   h r u g h u ,   n   l   l n g u g e',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'N _ r e',
#  'e   r u e   l g u e',
#  'l p c k   c n   n   l   l n g u g e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'l   c - f   c n',
#  'e   c r   c n ,   r u e   h u r   n   l n g u g e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'c n   v l e n c e ,   l n g u g e   n   r u e   h u r',
#  'l   u g g e v e   h u r',
#  'e q u e n c e   f   r l   r   c n',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'e   c r   g e ,   c n   n   r u e   h u r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'c r   n   n e n e   c r e u r e   c n   n   g e ,   n   f r   e   r u e   h u r',
#  'r l   r   c n   n   e   l   r u e   h u r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'r u e   h u r   n   e   c n',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'f n   c n / p e r l   n   e   l n g u g e',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'e r e   u l   l n g u g e   n   n e n e   c n',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'c n   e q u e n c e   n   p e r l',
#  'u l   c n e n   n   l   v l e n c e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'e   l   c n',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'l   c n   n   r u e   h u r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'c n   n   r u e   h u r',
#  'l   h e c   e l e e n',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'l n g u g e ,   e   c c   v l e n c e   n   l   e x - r e l e   h u r',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'f r   c n / p e r l ,   e   c r   e n   n   b r e f   r u e   h u r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'n e n e   c e n e   e l n g   w h   r n g   c n e n',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'l   h e c   e r l   n   l n g u g e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'e   c n   v l e n c e   n v l v n g   g u n p l ,   n   l   r u e   h u r',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'e   c r   e n',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'c r   g e ,   u g g e v e   e r l ,   e   l n g u g e   n   k n g',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'e   c r   g e ,   p e r l u   c n   e q u e n c e   n   l   r u e   h u r',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'r u e   n   u g g e v e   h u r ,   n   e   c n',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'e   r u e   h u r',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'l   h e c   e l e e n',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'v l e n c e   n   e n c n g   c n ,   r u e   h u r ,   u g g e v e   c n e n   n   h e c   e l e e n',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r .     C n e n   c n n   f n   v l e n c e .',
#  'e   p e r l',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   c h l r e n   g e   7   n   l e r',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'n l   c n   n   h u r',
#  'c n   v l e n c e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'e   c r   g e   n   c n ,   n   b r e f   l   l n g u g e',
#  'S u b l e   f r   l l   g e .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'l   l n g u g e   n   c n   e q u e n c e',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'l   l n g u g e   n   c c   c n',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'e   r u e   l n g u g e   n   p r n k',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'e   l   l n g u g e   n   r u g h   h c k e   c n',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   c h l r e n .',
#  'e   l ,   r u e   h u r',
#  'b r e f   l   l n g u g e   n   e   r u e   b e h v r',
#  'e   r e c k l e   b e h v r',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'e   l   h e c   e l e e n',
#  'P r e n l   g u n c e   u g g e e .   M   n   b e   u b l e   f r   l l   c h l r e n .',
#  'S u b l e   f r   l l   g e .',
#  'e   r u e   h u r   n   p r   c n',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'G e n e r l   A u e n c e .   S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .',
#  'S u b l e   f r   l l   g e .']

# %%
text = " ".join(rw for rw in corpus)
print ("There are {} words in the combination of all review.".format(len(text)))

# Generate a word cloud image
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 33261 words in the combination of all review.

# %% [markdown]
# # Dashboard

# %%
sns.set_style('dark')
f, axes=plt.subplots(2,2, figsize=(15,12))

# Kdeplot
axes[0,0].set_title("User Rating According To The Capacity", fontsize=20)
k1 = sns.kdeplot(netflix.RatingLevel, netflix.UserRating, shade=True, cmap='Blues_r',ax=axes[0,0])
k2 = sns.kdeplot(netflix.RatingLevel, netflix.UserRating, cmap='gist_gray_r',ax=axes[0,0])

# Stacked histogram
lis = []
leg = []
for gen in netflix.Rating.cat.categories:
    lis.append(netflix[netflix.Rating == gen].ReleaseYear)
    leg.append(gen)
axes[0,1].hist(lis, bins=30,stacked=True, rwidth=1, label=leg)
axes[0,1].set_title("Movie Rating Distribution ", fontsize=20)
axes[0,1].set_ylabel("Number of Movies", fontsize=15)
axes[0,1].set_xlabel("Rating", fontsize=15)
axes[0,1].legend(frameon=True, fancybox=True, shadow=True, prop={'size':10})

#Stacked histogram
axes[1,0].hist(netflix[netflix.ReleaseYear == 2016].Rating, color='slateblue')
axes[1,0].set_title("2016 Movie Distribution By Rated", fontsize=20)
axes[1,0].set_ylabel("Number of Movies", fontsize=15,)
axes[1,0].set_xlabel("Rated", fontsize=15)

# Word cloud
axes[1,1].set_title("Most Prominent Words in Rating Description \n", fontsize=20)
axes[1,1].imshow(wordcloud, interpolation='bilinear')
